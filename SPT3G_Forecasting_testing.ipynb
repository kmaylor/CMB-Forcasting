# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # TESTING FISHER_CMB.PY

# %% [markdown]
# ##  First lets try to remake the Fig 3 from Benson 2014

# %% [markdown]
# ### First import the necessary modules

# %%
from Fisher_CMB import *
from Models.SPT3G.spt3G_model import spt3G_model
from Models.Planck.Planck_model import planck_model
from pickle import load as pload
from Covariances.create_basic_cov import *

# %% [markdown]
# #### Best guess for the parameters used to make the figure WMAP + SPTSZ

# %%
params={'H0':72.5,#'cosmomc_theta': 1.0429e-2,
                           'ombh2':0.0223,
                           'omch2':0.1093,
                           'tau':0.083,
                           'As':2.142e-09,#*exp(2*0.068),
                           'ns':0.9623,
                           'lmax':6000,
                           'lens_potential_accuracy':2.0}

# %% [markdown]
# #### Create the covariances for SPT3G  and planck that will be saved to files

# %%
create_basic_cov(.06,array([0.00032*150/90,0.00032,0.00032*150/220]),[array([4.19262, 2.51558, 4.02493]),'ukarc'],
                     filename="Covariances/spt3G_cov_ell_200_5000.p",
                     time= 3.7e7,
                     specrange = (200,5000),
                     bin_size = 24,
                     spectra=('TT','EE','TE'),
                     params=params
                     )

# %%
create_basic_cov(.65,array([.00145]),[62,'uks'],
                     filename="Covariances/planck_cov_ell_2_5000.p",
                     time= 3.7e7,
                     specrange = (2,5000),
                     bin_size = 24,
                     spectra=('TT','EE','TE'),
                     params=params
                     )

# %% [markdown]
# #### load the pickled covariances

# %%
scov=pload(open( "Covariances/spt3G_cov_ell_200_5000.p", "rb" ))
pcov_ell_2_5000=pload(open( "Covariances/planck_cov_ell_2_5000.p", "rb" ))

# %% [markdown]
# ####  Creat models for SPT3G and Planck and cut out the portion that corresponds to D_b_EE

# %%
ms=spt3G_model(specrange = [('TT',(200,3000)),
                                ('EE',(200,5000)),
                                ('TE',(200,5000))],bin_size=24)
cmbs=ms(**params)[len(ms.windows['EE']):len(ms.windows['EE'])*2]

# %%
mp=planck_model(specrange = [('TT',(2,3000)),
                                ('EE',(2,5000)),
                                ('TE',(2,5000))],bin_size=24)
cmbp=mp(**params)[len(mp.windows['EE']):len(mp.windows['EE'])*2]

# %%
errorbar(dot(mp.windows['EE'],range(5000)[mp.windowrange['EE']]),cmbp,\
         yerr=sqrt(diag(pcov_ell_2_5000['EEEE'])),fmt='--',color='w',ecolor='b')

errorbar(dot(ms.windows['EE'],range(5000)[ms.windowrange['EE']]),cmbs,\
         yerr=sqrt(diag(scov['EEEE'])),fmt='--',color='y',ecolor='r')

yscale("log", nonposy='clip')
tick_params(which='both',top=True,right=True,labeltop=True,labelright=True)
ylim(0.01,70)
yticks([.01,.1,1,10])

xlim(0,5000)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 5000)

# %% [markdown]
# ##  Lets try looking at the constraints on Yp and Neff from SPT3G + Planck

# %% [markdown]
# #### Set the parameters, you can throw everything for the model in here, fish_params will be included in the covariance. The first number in fish_param is the fiducial model value, second is step size and the last is the optional prior.

# %%
params={'H0':None,'cosmomc_theta': fish_param(1.04106e-2,0.00041),
                           'ombh2':fish_param(0.02227,0.0002),
                           'ommh2':fish_param(0.1413,0.0011),
                           'tau':fish_param(0.067,0.013, 0.02),
                           'clamp':fish_param(1.873e-09,0.0115e-9),
                           'ns':fish_param( 0.9681,0.0044),
                           #'mnu':fish_param(.06,0.01),
                           'nnu':fish_param(3.046,0.03),
                           'YHe':fish_param(.252,.014),
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %% [markdown]
# ####  Calculate the fisher matrices for planck and spt

# %%
full_pcov = make_full_cov(['TT','EE','TE'],pcov_ell_2_5000)
Fp=Fisher_Matrix(params,full_pcov,
                 planck_model(specrange = [('TT',(2,3000)),('EE',(2,5000)),('TE',(2,5000))]))
# Out:
# [[  1.09100934e+05  -1.06941972e+14   2.06278678e+07   8.21982888e+03
#    -1.26236620e+05  -1.41800405e+05   2.37204573e+05  -7.40399323e+02]
#  [ -1.06941972e+14   1.55282410e+23  -4.06810940e+16  -6.11171536e+12
#     1.06157769e+14  -7.77056700e+13  -5.42584225e+14   1.38066864e+12]
#  [  2.06278678e+07  -4.06810940e+16   6.77421956e+10   3.85849991e+06
#    -4.61986224e+07  -4.06854116e+08   1.34443631e+08  -5.18221105e+05]
#  [  8.21982888e+03  -6.11171536e+12   3.85849991e+06   9.79118322e+02
#    -1.27482855e+04  -4.31591276e+04  -2.80798119e+03  -6.91783632e+01]
#  [ -1.26236620e+05   1.06157769e+14  -4.61986224e+07  -1.27482855e+04
#     2.00577398e+05  -2.76511889e+05  -1.03735898e+05  -1.25805950e+03]
#  [ -1.41800405e+05  -7.77056700e+13  -4.06854116e+08  -4.31591276e+04
#    -2.76511889e+05   4.01429805e+07   1.38641752e+06  -2.96529810e+04]
#  [  2.37204573e+05  -5.42584225e+14   1.34443631e+08  -2.80798119e+03
#    -1.03735898e+05   1.38641752e+06   2.87061947e+06  -2.01311107e+03]
#  [ -7.40399323e+02   1.38066864e+12  -5.18221105e+05  -6.91783632e+01
#    -1.25805950e+03  -2.96529810e+04  -2.01311107e+03   6.83396323e+03]]
# 0 YHe 0.0259966018399
# 1 clamp 2.29325875159e-11
# 2 cosmomc_theta 1.97074938269e-05
# 3 nnu 0.502413037092
# 4 ns 0.0127004066467
# 5 ombh2 0.000309471385569
# 6 ommh2 0.00732373328383
# 7 tau 0.0129964543019

# %%
full_scov = make_full_cov(['TT','EE','TE'],scov)
Fs=Fisher_Matrix(params,full_scov,spt3G_model(specrange = [('TT',(200,3000)),
                                ('EE',(200,5000)),
                                ('TE',(200,5000))]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-e25798db0617> in <module>()
#       2 Fs=Fisher_Matrix(params,full_scov,spt3G_model(specrange = [('TT',(200,3000)),
#       3                                 ('EE',(200,5000)),
# ----> 4                                 ('TE',(200,5000))]))
#
# /nfs/home/kmaylor/Forecasting/Fisher_CMB.py in Fisher_Matrix(params, cov, model, show_results)
#      42                                                                                if isinstance(v,fish_param)])
#      43     else:
# ---> 44         FM=(add_priors(params,Fisher_Calc(derivative(model,params),cov)), [k for k,v in params.items()
#      45                                                                            if isinstance(v,fish_param)])
#      46         print(FM[0])
#
# /nfs/home/kmaylor/Forecasting/Fisher_CMB.py in derivative(model, params)
#      76             tmp.update(base) #this update replaces all fish_params with base value and can now be fed to model
#      77             tmp[k]+=v.step/2
# ---> 78             modelu = model(**tmp)
#      79             tmp[k]-=v.step
#      80             modeld = model(**tmp)
#
# /nfs/home/kmaylor/Forecasting/Models/SPT3G/spt3G_model.py in __call__(self, **params)
#      51
#      52         #Calculate model for current params
# ---> 53         cmb = self.cmb(**params)
#      54         foregrounds = self.foregrounds(**params)
#      55         cals = {'TT':1/params.get('Tcal',1)**2,
#
# /nfs/home/kmaylor/Forecasting/Models/CMB/Fisher_camb.py in __call__(self, ALens, As, DoLensing, H0, cosmomc_theta, k_eta_max_scalar, lmax, massive_neutrinos, massless_neutrinos, mnu, nnu, NonLinear, ns, ombh2, omch2, omk, pivot_scalar, tau, YHe, AccuracyBoost, lens_potential_accuracy, nokwargs, spectra, **kwargs)
#      59         #feed params to camb and calulate power spectra, returned in specs
#      60         cp=self._camb.set_params(**params)
# ---> 61         self.result = self._camb.get_results(cp)
#      62         specs = self.result.get_cmb_power_spectra(spectra=['total','lens_potential'])
#      63
#
# ~/CAMB/pycamb/camb/camb.py in get_results(params)
#     951     """
#     952     res = CAMBdata()
# --> 953     res.calc_power_spectra(params)
#     954     return res
#     955
#
# ~/CAMB/pycamb/camb/camb.py in calc_power_spectra(self, params)
#     406         """
#     407         if params is not None:
# --> 408             result = self.calc_transfers(params, only_transfers=False)
#     409             if result != 0:
#     410                 raise CAMBError('Error getting transfer functions: %u' % result)
#
# ~/CAMB/pycamb/camb/camb.py in calc_transfers(self, params, only_transfers)
#     396         opt = c_bool()
#     397         opt.value = only_transfers
# --> 398         return CAMBdata_gettransfers(self._key, byref(params), byref(opt))
#     399
#     400     def calc_power_spectra(self, params=None):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Add matrices to get the joint constraint

# %%
Fps = Fp[0]+Fs[0]

# %% [markdown]
# ### Now some functions for making sloppy plots

# %% [markdown]
# #### make the x and y range in terms of sigma

# %%
def contour_range(mu,std,nsig=4,points=100):
    return linspace(mu-nsig*std,mu+nsig*std,points)

# %% [markdown]
# #### function for making the contours

# %%
def sig_contours(mu,sigma,colors='k'):
    x=contour_range(mu[0],sqrt(sigma[0,0]),nsig=5)
    y=contour_range(mu[1],sqrt(sigma[1,1]),nsig=5)
    X,Y=meshgrid(x,y)
    Z = bivariate_normal(X, Y, sigmax=sqrt(sigma[0,0]), sigmay=sqrt(sigma[1,1]),
                      mux=mu[0], muy=mu[1],sigmaxy=sigma[0,1])
    z1 = bivariate_normal(mu[0]+sqrt(sigma[0,0])*1, mu[1], sigmax=sqrt(sigma[0,0]), sigmay=sqrt(sigma[1,1]),
                      mux=mu[0], muy=mu[1],sigmaxy=sigma[0,1])
    z2 = bivariate_normal(mu[0]+sqrt(sigma[0,0])*2, mu[1], sigmax=sqrt(sigma[0,0]), sigmay=sqrt(sigma[1,1]),
                      mux=mu[0], muy=mu[1],sigmaxy=sigma[0,1])
        
    return contour(Y, X, Z,[z2,z1],colors=colors)

# %% [markdown]
# ### And throw everything together to make the plot

# %%
mu = [.252,3.046]
sigmap = array([[inv(Fp[0])[0,0],inv(Fp[0])[0,3]],[inv(Fp[0])[3,0],inv(Fp[0])[3,3]]])
sigmaps = array([[inv(Fps)[0,0],inv(Fps)[0,3]],[inv(Fps)[3,0],inv(Fps)[3,3]]])
xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$\rm{Y}_{\rm{p}}$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<3000,P:2<\ell<5000)$'+ \
'\n $LCDM$+$N_{eff}$+$Y_p$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mu,sigmap,colors = 'r')
cs1=sig_contours(mu,sigmaps,colors = 'k')
fmt1=dict(zip(cs1.levels,[r'$\textit{Planck}$+$\rm{SPT3G}$',r'$\textit{Planck}$+$\rm{SPT3G}$']))
fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))

clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2, fontsize=14)
clabel(cs1,cs1.levels[::2], inline=True, fmt=fmt1, fontsize=14)
xlabel(xlab, fontsize=14)
ylabel(ylab, fontsize=14)
title(titl)
tight_layout()
savefig('Figures/Yp_Neff_constraints_planck_and_planckSPT3G.pdf')

# %% [markdown]
# ## Now lets look at H0 and Omegabh^2 vs Neff with and without Planck ell>800

# %% [markdown]
# #### First make the fisher matrices need for LCDM+Neff

# %%
params={'H0':fish_param(67.90,0.55),#'cosmomc_theta': fish_param(1.04106e-2,0.00041),
                           'ombh2':fish_param(0.02227,0.0002),
                           'ommh2':fish_param(0.1413,0.0011),
                           'tau':fish_param(0.067,0.013, 0.02),
                           'clamp':fish_param(1.873e-09,0.0115e-9),
                           'ns':fish_param( 0.9681,0.0044),
                           'nnu':fish_param(3.046,0.03),
                           
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %%
Fp_5000_h0_neff=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_5000),planck_model(specrange = [('TT',(2,3000)),
                                ('EE',(2,5000)),
                                ('TE',(2,5000))]))

# %%
pcov_ell_2_800=pload(open( "Covariances/planck_cov_ell_2_800.p", "rb" ))

# %%
Fp_800_h0_neff=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_800),planck_model(specrange = [('TT',(2,800)),
                                ('EE',(2,800)),
                                ('TE',(2,800))]))

# %%
Fs_h0_neff=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],scov),spt3G_model(specrange = [('TT',(200,3000)),
                                ('EE',(200,5000)),
                                ('TE',(200,5000))]))

# %%
Fps_5000_h0_neff = Fp_5000_h0_neff[0]+Fs_h0_neff[0]
Fps_800_5000_h0_neff = Fp_800_h0_neff[0]+Fs_h0_neff[0]

# %% [markdown]
# #### And now the matrices for just LCDM

# %%
params={'H0':fish_param(67.90,0.55),#'cosmomc_theta': fish_param(1.04106e-2,0.00041),
                           'ombh2':fish_param(0.02227,0.0002),
                           'ommh2':fish_param(0.1413,0.0011),
                           'tau':fish_param(0.067,0.013, 0.02),
                           'clamp':fish_param(1.873e-09,0.0115e-9),
                           'ns':fish_param( 0.9681,0.0044),
                           #'nnu':fish_param(3.046,0.03),
                           
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %%
Fp_5000_h0=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_5000),planck_model(specrange = [('TT',(2,3000)),
                                ('EE',(2,5000)),
                                ('TE',(2,5000))]))

# %%
Fp_800_h0=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_800),planck_model(specrange = [('TT',(2,800)),
                                ('EE',(2,800)),
                                ('TE',(2,800))]))

# %%
Fs_h0=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],scov),spt3G_model(specrange = [('TT',(200,3000)),
                                ('EE',(200,5000)),
                                ('TE',(200,5000))]))

# %%
Fps_5000_h0 = Fp_5000_h0[0]+Fs_h0[0]
Fps_800_5000_h0 = Fp_800_h0[0]+Fs_h0[0]

# %% [markdown]
# ## Constraints on H0 and Neff with Full Planck Data

# %%
mu = [67.9,3.046]
sigmap = array([[inv(Fp_5000_h0_neff[0])[0,0],inv(Fp_5000_h0_neff[0])[0,2]],[inv(Fp_5000_h0_neff[0])[2,0],
                                                                    inv(Fp_5000_h0_neff[0])[2,2]]])
sigmaps = array([[inv(Fps_5000_h0_neff)[0,0],inv(Fps_5000_h0_neff)[0,2]],[inv(Fps_5000_h0_neff)[2,0],
                                                                inv(Fps_5000_h0_neff)[2,2]]])


xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$H_0$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<3000,P:2<\ell<5000)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mu,sigmap,colors = 'r')
cs1=sig_contours(mu,sigmaps,colors = 'k')

fmt1=dict(zip(cs1.levels,['P+SPT3G','P+SPT3G']))
fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs1,cs1.levels[::2], inline=True, fmt=fmt1,fontsize=14)
errorbar(mu[1],mu[0],yerr = sqrt(inv(Fp_5000_h0[0])[0,0]),color='r',elinewidth=8,label='Planck LCDM constraint on H0')
errorbar(mu[1],mu[0],yerr = sqrt(inv(Fps_5000_h0)[0,0]),color='k',elinewidth=6,label='Planck +SPT3G')

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
legend(loc='upper left')
ylim(60,78)
xlim(2.5,3.5)

tight_layout()
savefig('Figures/H0_Neff_constraints_planck_and_planckSPT3G.pdf')

# %% [markdown]
# ## Constraints on H0 and Neff with Planck (ell< 800)

# %%
mu = [67.9,3.046]
sigmap = array([[inv(Fp_800_h0_neff[0])[0,0],inv(Fp_800_h0_neff[0])[0,2]],[inv(Fp_800_h0_neff[0])[2,0],
                                                                    inv(Fp_800_h0_neff[0])[2,2]]])

sigmaps_800 = array([[inv(Fps_800_5000_h0_neff)[0,0],inv(Fps_800_5000_h0_neff)[0,2]],
                     [inv(Fps_800_5000_h0_neff)[2,0],inv(Fps_800_5000_h0_neff)[2,2]]])

xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$H_0$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<800,P:2<\ell<800)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mu,sigmap,colors = 'r')
cs3=sig_contours(mu,sigmaps_800,colors = 'g')

fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))
fmt3=dict(zip(cs3.levels,['P+SPT3G','P+SPT3G']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs3,cs3.levels[::2], inline=True, fmt=fmt3, fontsize=14)
errorbar(mu[1],mu[0],yerr = sqrt(inv(Fp_800_h0[0])[0,0]),color='r',elinewidth=8,label='Planck LCDM constraint on H0')
errorbar(mu[1],mu[0],yerr = sqrt(inv(Fps_800_5000_h0)[0,0]),color='g',elinewidth=6,label='Planck +SPT3G')

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
legend(loc='upper left')
ylim(60,78)
xlim(2.5,3.5)
tight_layout()

savefig('Figures/H0_Neff_constraints_planck_and_planck_800SPT3G.pdf')

# %% [markdown]
# ## Constraints on Omegabh^2 and Neff with Full Planck Data

# %%
mu = [0.0223,3.046]
sigmap = array([[inv(Fp_5000_h0_neff[0])[4,4],inv(Fp_5000_h0_neff[0])[4,2]],[inv(Fp_5000_h0_neff[0])[2,4],
                                                                    inv(Fp_5000_h0_neff[0])[2,2]]])
sigmaps = array([[inv(Fps_5000_h0_neff)[4,4],inv(Fps_5000_h0_neff)[4,2]],[inv(Fps_5000_h0_neff)[2,4],
                                                                inv(Fps_5000_h0_neff)[2,2]]])


xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$\Omega_bh^2$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<3000,P:2<\ell<5000)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mu,sigmap,colors = 'r')
cs1=sig_contours(mu,sigmaps,colors = 'k')

fmt1=dict(zip(cs1.levels,['P+SPT3G','P+SPT3G']))
fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs1,cs1.levels[::2], inline=True, fmt=fmt1,fontsize=14)
errorbar(0,0,yerr = 0,color='r',elinewidth=8,label='Planck ')
errorbar(0,0,yerr = 0,color='k',elinewidth=6,label='Planck +SPT3G')
legend(loc='upper left')

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
xlim(2,4)
ylim(.021,.0235)
tight_layout()
savefig('Figures/omegabh2_Neff_constraints_planck_and_planckSPT3G.pdf')

# %% [markdown]
# ## Constraints on Omegabh^2 and Neff with Planck (ell < 800)

# %%
mu = [0.0223,3.046]
sigmap = array([[inv(Fp_800_h0_neff[0])[4,4],inv(Fp_800_h0_neff[0])[4,2]],[inv(Fp_800_h0_neff[0])[2,4],
                                                                    inv(Fp_800_h0_neff[0])[2,2]]])

sigmaps_800 = array([[inv(Fps_800_5000_h0_neff)[4,4],inv(Fps_800_5000_h0_neff)[4,2]],
                     [inv(Fps_800_5000_h0_neff)[2,4],inv(Fps_800_5000_h0_neff)[2,2]]])

xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$\Omega_bh^2$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<800,P:2<\ell<800)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mu,sigmap,colors = 'r')
cs3=sig_contours(mu,sigmaps_800,colors = 'g')

fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))
fmt3=dict(zip(cs3.levels,['P+SPT3G','P+SPT3G']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs3,cs3.levels[::2], inline=True, fmt=fmt3, fontsize=14)
errorbar(0,0,yerr = 0,color='r',elinewidth=8,label='Planck ')
errorbar(0,0,yerr = 0,color='g',elinewidth=6,label='Planck +SPT3G')
legend(loc='upper left')

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
xlim(2,4)
ylim(.021,.0235)
tight_layout()
savefig('Figures/omegabh2_Neff_constraints_planck_and_planck_800SPT3G.pdf')

# %% [markdown]
# ## One more test, make the left panel of Figure 23 from the S4 science book

# %% [markdown]
# #### We will do this for a 1' beam the y axis is the constraint on Neff and the x axis is the sky fraction

# %% [markdown]
# #### My result is a bit off. For fsky = .4 the constraint on Neff is .03 in the science book but I get .04. If I reduced the covariance by a factor of two I get a more similar result

# %%
params={'H0':None,'cosmomc_theta': fish_param(1.0438e-2,1.3e-5),
                           'ombh2':fish_param(0.0223,0.001),
                           'ommh2':fish_param(0.13,0.007),
                           'tau':fish_param(0.083,0.02, 0.02),
                           'clamp':fish_param(1.93e-09,4.5e-11),
                           'ns':fish_param(0.9623,0.032),
                           'nnu':fish_param(3.046,0.03),
                           
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %% [markdown]
# #### This next cell can take some time depending on your machine, you might want to get some coffee.
# We are calculating 8 fisher matrices for 7 parameters and camb gets called twice for each parameter, so 112 calls to camb

# %%
results=[]
for fsky in arange(.1,.9,.1):
    s4cov=create_basic_cov(fsky,.0003,[sqrt(fsky/.4),'ukarc'],
                     specrange = (30,5000),
                     bin_size = 24,
                     spectra=('TT','EE','TE'),
                     )
    Fs4=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],s4cov),
                 planck_model(bin_size=24,specrange = [('TT',(30,3000)),('EE',(30,5000)),('TE',(30,5000))]))[0]
    results.append((fsky,sqrt(inv(Fs4)[2,2])))
# Out:
# [[  1.03652014e+24  -7.12627067e+17  -2.31325786e+14   2.11431530e+15
#     4.57966893e+16  -1.40315387e+15  -3.05631714e+12]
#  [ -7.12627067e+17   5.16765215e+12   1.93013390e+08  -1.83977294e+09
#    -4.03783733e+10   3.05976645e+09   2.59275124e+06]
#  [ -2.31325786e+14   1.93013390e+08   7.16156888e+04  -5.98862529e+05
#    -1.60067492e+07   1.23977518e+04   8.80126613e+02]
#  [  2.11431530e+15  -1.83977294e+09  -5.98862529e+05   5.24163109e+06
#     1.26160244e+08  -9.20226103e+05  -9.20041911e+03]
#  [  4.57966893e+16  -4.03783733e+10  -1.60067492e+07   1.26160244e+08
#     4.74393914e+09   1.00844977e+07  -1.57610000e+05]
#  [ -1.40315387e+15   3.05976645e+09   1.23977518e+04  -9.20226103e+05
#     1.00844977e+07   9.95565045e+06   3.38814663e+02]
#  [ -3.05631714e+12   2.59275124e+06   8.80126613e+02  -9.20041911e+03
#    -1.57610000e+05   3.38814663e+02   2.68419186e+03]]
# 0 clamp 4.67943962049e-12
# 1 cosmomc_theta 6.52519651176e-07
# 2 nnu 0.0284443938608
# 3 ns 0.0032100608292
# 4 ombh2 3.44248741301e-05
# 5 ommh2 0.000748559946327
# 6 tau 0.0194357010495

# %%
fskys,Neffs=zip(*results)

# %%
plot(fskys,array(Neffs))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from __future__ import unicode_literals
import pandas as p

# %%
store=p.HDFStore("/home/kmaylor/Python_Projects/PlanckVSPT/real_tau_0.07.hdf",mode='r')

# %%
df = p.DataFrame(store['/root'])
df.to_hdf('new_real_tau_0.07.h5','data',format='table')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-c522096acf0b> in <module>()
#       1 df = p.DataFrame(store['/root'])
# ----> 2 df.to_hdf('new_real_tau_0.07.h5','data',format='table')
#
# /usr/lib/python2.7/dist-packages/pandas/core/generic.pyc in to_hdf(self, path_or_buf, key, **kwargs)
#     882
#     883         from pandas.io import pytables
# --> 884         return pytables.to_hdf(path_or_buf, key, self, **kwargs)
#     885
#     886     def to_msgpack(self, path_or_buf=None, **kwargs):
#
# /usr/lib/python2.7/dist-packages/pandas/io/pytables.pyc in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, **kwargs)
#     277         with get_store(path_or_buf, mode=mode, complevel=complevel,
#     278                        complib=complib) as store:
# --> 279             f(store)
#     280     else:
#     281         f(path_or_buf)
#
# /usr/lib/python2.7/dist-packages/pandas/io/pytables.pyc in <lambda>(store)
#     272         f = lambda store: store.append(key, value, **kwargs)
#     273     else:
# --> 274         f = lambda store: store.put(key, value, **kwargs)
#     275
#     276     if isinstance(path_or_buf, compat.string_types):
#
# /usr/lib/python2.7/dist-packages/pandas/io/pytables.pyc in put(self, key, value, format, append, **kwargs)
#     819             format = get_option("io.hdf.default_format") or 'fixed'
#     820         kwargs = self._validate_format(format, kwargs)
# --> 821         self._write_to_group(key, value, append=append, **kwargs)
#     822
#     823     def remove(self, key, where=None, start=None, stop=None):
#
# /usr/lib/python2.7/dist-packages/pandas/io/pytables.pyc in _write_to_group(self, key, value, format, index, append, complib, encoding, **kwargs)
#    1271
#    1272         # write the object
# -> 1273         s.write(obj=value, append=append, complib=complib, **kwargs)
#    1274
#    1275         if s.is_table and index:
#
# /usr/lib/python2.7/dist-packages/pandas/io/pytables.pyc in write(self, obj, axes, append, complib, complevel, fletcher32, min_itemsize, chunksize, expectedrows, dropna, **kwargs)
#    3576         self.create_axes(axes=axes, obj=obj, validate=append,
#    3577                          min_itemsize=min_itemsize,
# -> 3578                          **kwargs)
#    3579
#    3580         if not self.is_exists:
#
# /usr/lib/python2.7/dist-packages/pandas/io/pytables.pyc in create_axes(self, axes, obj, validate, nan_rep, data_columns, min_itemsize, **kwargs)
#    3271                 self.values_axes.append(col)
#    3272             except (NotImplementedError, ValueError, TypeError) as e:
# -> 3273                 raise e
#    3274             except Exception as detail:
#    3275                 raise Exception(
#
# TypeError: Cannot serialize the column [(2, 650)] because
# its data contents are [mixed-integer] object dtype

# %%
new_real_tau=p.HDFStore('new_real_tau_0.07.h5')

# %%
a=store['/root'][2]

# %%
a
# Out:
#                                                              700   \
# calPlanck                                                1.000556
# clTT            [0.0, 0.0, 1076.52543888, 504.47664035, 283.96...
# cosmo.H0                                                 70.48835
# cosmo.clamp                                              1.861092
# cosmo.logA                                               3.062582
# cosmo.ns                                                0.9820207
# cosmo.ombh2                                            0.02283855
# cosmo.omch2                                             0.1147096
# cosmo.ommh2                                             0.1375482
# cosmo.s8omm1/4                                          0.5842263
# cosmo.sigma8                                            0.8054268
# cosmo.tau                                              0.06941658
# cosmo.theta                                              1.043402
# highl_chi2                                               62.64468
# highl_dof                                                      80
# lnl                                                      37.06055
#
#                                                              750   \
# calPlanck                                                1.000574
# clTT            [0.0, 0.0, 1091.18954793, 511.020174777, 287.4...
# cosmo.H0                                                 70.13354
# cosmo.clamp                                              1.851819
# cosmo.logA                                               3.058025
# cosmo.ns                                                0.9779295
# cosmo.ombh2                                            0.02264249
# cosmo.omch2                                             0.1141128
# cosmo.ommh2                                             0.1367553
# cosmo.s8omm1/4                                          0.5809102
# cosmo.sigma8                                            0.7999924
# cosmo.tau                                               0.0696358
# cosmo.theta                                              1.042185
# highl_chi2                                               67.51537
# highl_dof                                                      86
# lnl                                                      39.64173
#
#                                                              800   \
# calPlanck                                                1.000592
# clTT            [0.0, 0.0, 1092.76732478, 511.991036446, 288.1...
# cosmo.H0                                                 70.05819
# cosmo.clamp                                              1.852089
# cosmo.logA                                               3.057893
# cosmo.ns                                                0.9770048
# cosmo.ombh2                                            0.02261114
# cosmo.omch2                                              0.114276
# cosmo.ommh2                                             0.1368871
# cosmo.s8omm1/4                                           0.581686
# cosmo.sigma8                                            0.8004375
# cosmo.tau                                              0.06949676
# cosmo.theta                                              1.042219
# highl_chi2                                               73.37652
# highl_dof                                                      91
# lnl                                                      42.62831
#
#                                                              850   \
# calPlanck                                                1.000617
# clTT            [0.0, 0.0, 1086.11003682, 509.129652045, 286.6...
# cosmo.H0                                                 69.94202
# cosmo.clamp                                              1.852599
# cosmo.logA                                               3.058203
# cosmo.ns                                                0.9780085
# cosmo.ombh2                                            0.02263422
# cosmo.omch2                                             0.1142692
# cosmo.ommh2                                             0.1369035
# cosmo.s8omm1/4                                          0.5821717
# cosmo.sigma8                                            0.8004175
# cosmo.tau                                              0.06951408
# cosmo.theta                                              1.041813
# highl_chi2                                               77.66612
# highl_dof                                                      97
# lnl                                                      44.70258
#
#                                                              950   \
# calPlanck                                                1.000542
# clTT            [0.0, 0.0, 1078.09630188, 506.345807496, 285.4...
# cosmo.H0                                                 69.40828
# cosmo.clamp                                              1.856556
# cosmo.logA                                               3.062327
# cosmo.ns                                                0.9783857
# cosmo.ombh2                                            0.02262193
# cosmo.omch2                                             0.1148154
# cosmo.ommh2                                             0.1374373
# cosmo.s8omm1/4                                          0.5872325
# cosmo.sigma8                                            0.8035068
# cosmo.tau                                              0.07050941
# cosmo.theta                                              1.040866
# highl_chi2                                               81.46067
# highl_dof                                                     108
# lnl                                                      46.57896
#
#                                                              1000  \
# calPlanck                                                1.000606
# clTT            [0.0, 0.0, 1077.98924353, 506.454809059, 285.5...
# cosmo.H0                                                 69.32659
# cosmo.clamp                                               1.85684
# cosmo.logA                                                3.06358
# cosmo.ns                                                 0.978312
# cosmo.ombh2                                            0.02261244
# cosmo.omch2                                             0.1149243
# cosmo.ommh2                                             0.1375367
# cosmo.s8omm1/4                                          0.5883012
# cosmo.sigma8                                            0.8043498
# cosmo.tau                                              0.07105928
# cosmo.theta                                              1.040767
# highl_chi2                                               86.32209
# highl_dof                                                     114
# lnl                                                      49.02002
#
#                                                              1050  \
# calPlanck                                                1.000611
# clTT            [0.0, 0.0, 1078.25421844, 506.998750187, 286.0...
# cosmo.H0                                                 69.00761
# cosmo.clamp                                              1.858388
# cosmo.logA                                               3.058396
# cosmo.ns                                                0.9757965
# cosmo.ombh2                                             0.0225556
# cosmo.omch2                                             0.1154763
# cosmo.ommh2                                             0.1380318
# cosmo.s8omm1/4                                          0.5896378
# cosmo.sigma8                                            0.8035983
# cosmo.tau                                              0.06805096
# cosmo.theta                                              1.040563
# highl_chi2                                               94.89617
# highl_dof                                                     119
# lnl                                                       53.4307
#
#                                                              1100  \
# calPlanck                                                1.000459
# clTT            [0.0, 0.0, 1066.68013209, 500.271172945, 281.7...
# cosmo.H0                                                 69.97195
# cosmo.clamp                                              1.853605
# cosmo.logA                                               3.059714
# cosmo.ns                                                0.9825157
# cosmo.ombh2                                            0.02274751
# cosmo.omch2                                              0.113843
# cosmo.ommh2                                             0.1365905
# cosmo.s8omm1/4                                          0.5812445
# cosmo.sigma8                                            0.7997711
# cosmo.tau                                              0.06999847
# cosmo.theta                                              1.041156
# highl_chi2                                                102.218
# highl_dof                                                     125
# lnl                                                      56.72532
#
#                                                              1150  \
# calPlanck                                                1.000671
# clTT            [0.0, 0.0, 1084.80909318, 510.290052947, 287.9...
# cosmo.H0                                                 68.89267
# cosmo.clamp                                               1.85985
# cosmo.logA                                               3.063081
# cosmo.ns                                                0.9748539
# cosmo.ombh2                                            0.02251267
# cosmo.omch2                                             0.1158125
# cosmo.ommh2                                             0.1383252
# cosmo.s8omm1/4                                          0.5927325
# cosmo.sigma8                                            0.8067147
# cosmo.tau                                                    0.07
# cosmo.theta                                              1.040692
# highl_chi2                                               106.0727
# highl_dof                                                     130
# lnl                                                      59.11623
#
#                                                              1200  \
# calPlanck                                                1.000647
# clTT            [0.0, 0.0, 1090.87431741, 513.618073244, 289.9...
# cosmo.H0                                                 68.57981
# cosmo.clamp                                              1.862598
# cosmo.logA                                               3.065078
# cosmo.ns                                                 0.972636
# cosmo.ombh2                                            0.02244912
# cosmo.omch2                                             0.1164779
# cosmo.ommh2                                             0.1389271
# cosmo.s8omm1/4                                          0.5967595
# cosmo.sigma8                                              0.80947
# cosmo.tau                                              0.07026053
# cosmo.theta                                              1.040639
# highl_chi2                                               109.9817
# highl_dof                                                     136
# lnl                                                       61.2497
#
#                                                              1250  \
# calPlanck                                                 1.00071
# clTT            [0.0, 0.0, 1098.24684312, 517.371929544, 292.2...
# cosmo.H0                                                 68.38147
# cosmo.clamp                                              1.865483
# cosmo.logA                                               3.065941
# cosmo.ns                                                0.9703483
# cosmo.ombh2                                            0.02238292
# cosmo.omch2                                             0.1170951
# cosmo.ommh2                                              0.139478
# cosmo.s8omm1/4                                          0.5999426
# cosmo.sigma8                                            0.8118064
# cosmo.tau                                              0.06991805
# cosmo.theta                                              1.040876
# highl_chi2                                                122.258
# highl_dof                                                     141
# lnl                                                      67.59698
#
#                                                              1300  \
# calPlanck                                                1.000712
# clTT            [0.0, 0.0, 1103.86716577, 520.054471812, 293.6...
# cosmo.H0                                                 68.27614
# cosmo.clamp                                              1.866684
# cosmo.logA                                               3.070269
# cosmo.ns                                                0.9698525
# cosmo.ombh2                                            0.02239271
# cosmo.omch2                                             0.1174254
# cosmo.ommh2                                             0.1398181
# cosmo.s8omm1/4                                             0.6028
# cosmo.sigma8                                            0.8145483
# cosmo.tau                                              0.07176027
# cosmo.theta                                              1.040892
# highl_chi2                                               131.0946
# highl_dof                                                     147
# lnl                                                      72.10326
#
#                                                              1350  \
# calPlanck                                                1.000642
# clTT            [0.0, 0.0, 1106.65966981, 521.656913425, 294.6...
# cosmo.H0                                                 68.22971
# cosmo.clamp                                              1.869102
# cosmo.logA                                               3.074027
# cosmo.ns                                                0.9694725
# cosmo.ombh2                                            0.02243162
# cosmo.omch2                                             0.1178487
# cosmo.ommh2                                             0.1402803
# cosmo.s8omm1/4                                          0.6056722
# cosmo.sigma8                                            0.8174765
# cosmo.tau                                              0.07299194
# cosmo.theta                                              1.041111
# highl_chi2                                               138.4675
# highl_dof                                                     152
# lnl                                                      75.87941
#
#                                                              1400  \
# calPlanck                                                1.000687
# clTT            [0.0, 0.0, 1106.78551911, 521.72898481, 294.71...
# cosmo.H0                                                 68.21163
# cosmo.clamp                                               1.86923
# cosmo.logA                                               3.073874
# cosmo.ns                                                  0.96935
# cosmo.ombh2                                            0.02242767
# cosmo.omch2                                             0.1179211
# cosmo.ommh2                                             0.1403488
# cosmo.s8omm1/4                                          0.6059754
# cosmo.sigma8                                            0.8176774
# cosmo.tau                                              0.07288119
# cosmo.theta                                              1.041144
# highl_chi2                                               143.0756
# highl_dof                                                     158
# lnl                                                      78.19161
#
#                                                              1450  \
# calPlanck                                                1.000671
# clTT            [0.0, 0.0, 1117.27766606, 526.821285541, 297.5...
# cosmo.H0                                                 68.00551
# cosmo.clamp                                              1.871974
# cosmo.logA                                               3.081183
# cosmo.ns                                                0.9682093
# cosmo.ombh2                                            0.02237219
# cosmo.omch2                                             0.1183994
# cosmo.ommh2                                             0.1407716
# cosmo.s8omm1/4                                          0.6107525
# cosmo.sigma8                                            0.8222588
# cosmo.tau                                              0.07580253
# cosmo.theta                                              1.041175
# highl_chi2                                               151.9881
# highl_dof                                                     164
# lnl                                                      82.87066
#
#                                                              1500  \
# calPlanck                                                1.000687
# clTT            [0.0, 0.0, 1126.26918607, 531.52306857, 300.32...
# cosmo.H0                                                 67.71848
# cosmo.clamp                                              1.874106
# cosmo.logA                                               3.087372
# cosmo.ns                                                0.9665491
# cosmo.ombh2                                            0.02227756
# cosmo.omch2                                             0.1189527
# cosmo.ommh2                                             0.1412303
# cosmo.s8omm1/4                                          0.6157668
# cosmo.sigma8                                            0.8265858
# cosmo.tau                                              0.07832769
# cosmo.theta                                              1.041137
# highl_chi2                                               159.0791
# highl_dof                                                     169
# lnl                                                      86.68624
#
#                                                              1550  \
# calPlanck                                                1.000727
# clTT            [0.0, 0.0, 1119.5118407, 528.256872209, 298.50...
# cosmo.H0                                                 67.82149
# cosmo.clamp                                              1.873231
# cosmo.logA                                               3.083002
# cosmo.ns                                                 0.967258
# cosmo.ombh2                                            0.02230346
# cosmo.omch2                                             0.1187511
# cosmo.ommh2                                             0.1410546
# cosmo.s8omm1/4                                          0.6133503
# cosmo.sigma8                                            0.8242244
# cosmo.tau                                              0.07637594
# cosmo.theta                                              1.041168
# highl_chi2                                               164.4209
# highl_dof                                                     172
# lnl                                                      89.19954
#
#                                                              1600  \
# calPlanck                                                1.000761
# clTT            [0.0, 0.0, 1132.67770598, 534.50199053, 301.96...
# cosmo.H0                                                 67.58332
# cosmo.clamp                                              1.873499
# cosmo.logA                                               3.086857
# cosmo.ns                                                0.9649097
# cosmo.ombh2                                            0.02223738
# cosmo.omch2                                             0.1191175
# cosmo.ommh2                                             0.1413549
# cosmo.s8omm1/4                                          0.6164389
# cosmo.sigma8                                            0.8264795
# cosmo.tau                                              0.07823219
# cosmo.theta                                              1.041006
# highl_chi2                                                165.878
# highl_dof                                                     175
# lnl                                                      90.24081
#
#                                                              1650  \
# calPlanck                                                1.000755
# clTT            [0.0, 0.0, 1132.54387102, 534.53843487, 302.03...
# cosmo.H0                                                 67.56452
# cosmo.clamp                                              1.873397
# cosmo.logA                                               3.086625
# cosmo.ns                                                0.9647015
# cosmo.ombh2                                            0.02222299
# cosmo.omch2                                             0.1191481
# cosmo.ommh2                                             0.1413711
# cosmo.s8omm1/4                                          0.6165554
# cosmo.sigma8                                            0.8264971
# cosmo.tau                                              0.07814345
# cosmo.theta                                              1.041018
# highl_chi2                                                166.368
# highl_dof                                                     178
# lnl                                                      90.49868
#
#                                                              1700
# calPlanck                                                1.000733 ...
# clTT            [0.0, 0.0, 1133.04389465, 535.005731212, 302.3... ...
# cosmo.H0                                                 67.44638 ...
# cosmo.clamp                                              1.874844 ...
# cosmo.logA                                               3.088593 ...
# cosmo.ns                                                0.9645029 ...
# cosmo.ombh2                                            0.02221655 ...
# cosmo.omch2                                             0.1193793 ...
# cosmo.ommh2                                             0.1415958 ...
# cosmo.s8omm1/4                                          0.6184475 ...
# cosmo.sigma8                                            0.8279794 ...
# cosmo.tau                                              0.07874119 ...
# cosmo.theta                                              1.040924 ...
# highl_chi2                                               168.8431 ...
# highl_dof                                                     181 ...
# lnl                                                      91.79302 ...
#
# [16 rows x 36 columns]
