# %%
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /nfs/home/kmaylor/.virtualenvs/Forecasting_env/local/lib/python3.4/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['mean']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from Fisher_CMB import *
from Models.SPT3G.spt3G_model import spt3G_model
from Models.Planck.Planck_model import planck_model
from pickle import load
from Models.COVS.create_basic_cov import *

# %%
params={'H0':72.5,#'cosmomc_theta': 1.0429e-2,
                           'ombh2':0.0223,
                           'omch2':0.1093,
                           'tau':0.083,
                           'As':2.142e-09,#*exp(2*0.068),
                           'ns':0.9623,
                           'lmax':6000,
                           'lens_potential_accuracy':2.0}

# %%
create_basic_cov(.06,.0003,"Models/COVS/spt3G_cov_ell_200_5000.p",
                     noise=(2.5,'ukarc'),
                     time= 3.7e7,
                     windowrange = slice(200,5000),
                     bin_size = 24,
                     spectra=('TT','EE','TE'),
                     params=params
                     )

# %%
create_basic_cov(.65,.00145,"Models/COVS/planck_cov_ell_2_800.p",
                     noise=(62,'uks'),
                     time= 3.7e7,
                     windowrange = slice(2,800),
                     bin_size = 24,
                     spectra=('TT','EE','TE'),
                     params=params
                     )

# %%
scov=load(open( "Models/COVS/spt3G_cov_ell_200_5000.p", "rb" ))
pcov_ell_2_5000=load(open( "Models/COVS/planck_cov_ell_2_5000.p", "rb" ))
pcov_ell_2_800=load(open( "Models/COVS/planck_cov_ell_2_800.p", "rb" ))

# %%
ms=spt3G_model(specrange = [('TT',slice(200,3000)),
                                ('EE',slice(200,5000)),
                                ('TE',slice(200,5000))],bin_size=24)
cmbs=ms(**params)[len(ms.windows['EE']):len(ms.windows['EE'])*2]

# %%
mp=planck_model(specrange = [('TT',slice(2,3000)),
                                ('EE',slice(2,5000)),
                                ('TE',slice(2,5000))],bin_size=24)
cmbp=mp(**params)[len(mp.windows['EE']):len(mp.windows['EE'])*2]

# %%
errorbar(dot(mp.windows['EE'],range(5000)[mp.windowrange['EE']]),cmbp,yerr=sqrt(diag(pcov_ell_2_5000['EEEE']))/sqrt(2),fmt='--',color='w',ecolor='b')
errorbar(dot(ms.windows['EE'],range(5000)[ms.windowrange['EE']]),cmbs,yerr=sqrt(diag(scov['EEEE']))/sqrt(2),fmt='--',color='y',ecolor='r')
yscale("log", nonposy='clip')
tick_params(which='both',top=True,right=True,labeltop=True,labelright=True)
ylim(0.01,70)
yticks([.01,.1,1,10])

xlim(0,5000)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 5000)

# %%
params={'H0':None,'cosmomc_theta': fish_param(1.04106e-2,0.00041),
                           'ombh2':fish_param(0.02227,0.0002),
                           'ommh2':fish_param(0.1413,0.0011),
                           'tau':fish_param(0.067,0.013, 0.02),
                           'clamp':fish_param(1.873e-09,0.0115e-9),
                           'ns':fish_param( 0.9681,0.0044),
                           #'mnu':fish_param(.06,0.01),
                           'nnu':fish_param(3.046,0.03),
                           'YHe':fish_param(.252,.014),
                           #'Asz':fish_param(5.5,3.0,3.0),
                           #'Aps':fish_param(19.3,3.5,3.5),
                           #'Acib':fish_param(5.,2.5,2.5),
                           #'Tcal':fish_param(1.0087,.0015,.0015),
                           #'Pcal':fish_param(1,0.01,.01),
                           #'A_TE80':fish_param(1.5,.5),
                           #'A_EE80':fish_param(1.5,.5),
                           #'a_TE':fish_param(-2.42,.02,.02),
                           #'a_EE':fish_param(-2.42,.02,.02),
                           #'D_PSEE_3000': fish_param(2.,.5),
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %%
Fp=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_5000)/2,
                 planck_model(specrange = [('TT',slice(2,3000)),('EE',slice(2,5000)),('TE',slice(2,5000))]))
# Out:
# 0 YHe 0.0187516431218
# 1 clamp 1.65493595433e-11
# 2 cosmomc_theta 1.42101306351e-05
# 3 nnu 0.362758934185
# 4 ns 0.00925074086338
# 5 ombh2 0.000225286930567
# 6 ommh2 0.00528255427292
# 7 tau 0.0101128265114

# %%
Fs=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],scov)/2,spt3G_model(specrange = [('TT',slice(200,3000)),
                                ('EE',slice(200,5000)),
                                ('TE',slice(200,5000))]))
# Out:
# 0 YHe 0.01568607035
# 1 clamp 1.62766101251e-11
# 2 cosmomc_theta 9.94513362505e-06
# 3 nnu 0.303092719457
# 4 ns 0.00938898876017
# 5 ombh2 9.51360404011e-05
# 6 ommh2 0.00467879971333
# 7 tau 0.0133665802897

# %%
Fps = Fp[0]+Fs[0]

# %%
def contour_range(mean,std,nsig=4,points=100):
    return linspace(mean-nsig*std,mean+nsig*std,points)

# %%
def sig_contours(mu,sigma,colors='k'):
    x=contour_range(mu[0],sqrt(sigma[0,0]),nsig=5)
    y=contour_range(mu[1],sqrt(sigma[1,1]),nsig=5)
    X,Y=meshgrid(x,y)
    Z = bivariate_normal(X, Y, sigmax=sqrt(sigma[0,0]), sigmay=sqrt(sigma[1,1]),
                      mux=mu[0], muy=mu[1],sigmaxy=sigma[0,1])
    z1 = bivariate_normal(mu[0]+sqrt(sigma[0,0])*1, mu[1], sigmax=sqrt(sigma[0,0]), sigmay=sqrt(sigma[1,1]),
                      mux=mu[0], muy=mu[1],sigmaxy=sigma[0,1])
    z2 = bivariate_normal(mu[0]+sqrt(sigma[0,0])*2, mu[1], sigmax=sqrt(sigma[0,0]), sigmay=sqrt(sigma[1,1]),
                      mux=mu[0], muy=mu[1],sigmaxy=sigma[0,1])
        
    return contour(Y, X, Z,[z2,z1],colors=colors)

# %%
mean = [.252,3.046]
sigmap = array([[inv(Fp[0])[0,0],inv(Fp[0])[0,3]],[inv(Fp[0])[3,0],inv(Fp[0])[3,3]]])
sigmaps = array([[inv(Fps)[0,0],inv(Fps)[0,3]],[inv(Fps)[3,0],inv(Fps)[3,3]]])
xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$\rm{Y}_{\rm{p}}$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<3000,P:2<\ell<5000)$'+ \
'\n $LCDM$+$N_{eff}$+$Y_p$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mean,sigmap,colors = 'r')
cs1=sig_contours(mean,sigmaps,colors = 'k')
fmt1=dict(zip(cs1.levels,[r'$\textit{Planck}$+$\rm{SPT3G}$',r'$\textit{Planck}$+$\rm{SPT3G}$']))
fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))

clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2, fontsize=14)
clabel(cs1,cs1.levels[::2], inline=True, fmt=fmt1, fontsize=14)
xlabel(xlab, fontsize=14)
ylabel(ylab, fontsize=14)
title(titl)
tight_layout()
savefig('Figures/Yp_Neff_constraints_planck_and_planckSPT3G.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
params={'H0':fish_param(67.90,0.55),#'cosmomc_theta': fish_param(1.04106e-2,0.00041),
                           'ombh2':fish_param(0.02227,0.0002),
                           'ommh2':fish_param(0.1413,0.0011),
                           'tau':fish_param(0.067,0.013, 0.02),
                           'clamp':fish_param(1.873e-09,0.0115e-9),
                           'ns':fish_param( 0.9681,0.0044),
                           'nnu':fish_param(3.046,0.03),
                           
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %%
Fp_5000_h0_neff=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_5000)/2,planck_model(specrange = [('TT',slice(2,3000)),
                                ('EE',slice(2,5000)),
                                ('TE',slice(2,5000))]))
# Out:
# 0 H0 1.54639353458
# 1 clamp 1.27328004946e-11
# 2 nnu 0.179305018653
# 3 ns 0.00908066146619
# 4 ombh2 0.000225968177006
# 5 ommh2 0.00266780516193
# 6 tau 0.0101279078633

# %%
Fp_800_h0_neff=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_800)/2,planck_model(specrange = [('TT',slice(2,800)),
                                ('EE',slice(2,800)),
                                ('TE',slice(2,800))]))
# Out:
# 0 H0 2.34436410614
# 1 clamp 2.71421409737e-11
# 2 nnu 0.374059807624
# 3 ns 0.0119500023034
# 4 ombh2 0.000298892013916
# 5 ommh2 0.00623539792384
# 6 tau 0.0103317467186

# %%
Fs_h0_neff=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],scov)/2,spt3G_model(specrange = [('TT',slice(200,3000)),
                                ('EE',slice(200,5000)),
                                ('TE',slice(200,5000))]))
# Out:
# 0 H0 0.9449108794
# 1 clamp 1.11994800427e-11
# 2 nnu 0.105051425553
# 3 ns 0.00947024330025
# 4 ombh2 9.56035727148e-05
# 5 ommh2 0.00221594242545
# 6 tau 0.0132196452566

# %%
Fps_5000_h0_neff = Fp_5000_h0_neff[0]+Fs_h0_neff[0]
Fps_800_5000_h0_neff = Fp_800_h0_neff[0]+Fs_h0_neff[0]

# %%
params={'H0':fish_param(67.90,0.55),#'cosmomc_theta': fish_param(1.04106e-2,0.00041),
                           'ombh2':fish_param(0.02227,0.0002),
                           'ommh2':fish_param(0.1413,0.0011),
                           'tau':fish_param(0.067,0.013, 0.02),
                           'clamp':fish_param(1.873e-09,0.0115e-9),
                           'ns':fish_param( 0.9681,0.0044),
                           #'nnu':fish_param(3.046,0.03),
                           
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %%
Fp_5000_h0=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_5000)/2,planck_model(specrange = [('TT',slice(2,3000)),
                                ('EE',slice(2,5000)),
                                ('TE',slice(2,5000))]))
# Out:
# 0 H0 0.63837132582
# 1 clamp 6.89828677237e-12
# 2 ns 0.00380475047128
# 3 ombh2 0.000141069920772
# 4 ommh2 0.00134000579939
# 5 tau 0.00965219481577

# %%
Fp_800_h0=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],pcov_ell_2_800)/2,planck_model(specrange = [('TT',slice(2,800)),
                                ('EE',slice(2,800)),
                                ('TE',slice(2,800))]))
# Out:
# 0 H0 1.04063529827
# 1 clamp 8.61731592514e-12
# 2 ns 0.00763405939877
# 3 ombh2 0.000251805856388
# 4 ommh2 0.00181642005306
# 5 tau 0.0102437973291

# %%
Fs_h0=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],scov)/2,spt3G_model(specrange = [('TT',slice(200,3000)),
                                ('EE',slice(200,5000)),
                                ('TE',slice(200,5000))]))
# Out:
# 0 H0 0.603572579555
# 1 clamp 1.06784940968e-11
# 2 ns 0.00528299722011
# 3 ombh2 7.04431133798e-05
# 4 ommh2 0.00158441366597
# 5 tau 0.0127991503656

# %%
Fps_5000_h0 = Fp_5000_h0[0]+Fs_h0[0]
Fps_800_5000_h0 = Fp_800_h0[0]+Fs_h0[0]

# %%
mean = [72.5,3.046]
sigmap = array([[inv(Fp_5000_h0_neff[0])[0,0],inv(Fp_5000_h0_neff[0])[0,2]],[inv(Fp_5000_h0_neff[0])[2,0],
                                                                    inv(Fp_5000_h0_neff[0])[2,2]]])
sigmaps = array([[inv(Fps_5000_h0_neff)[0,0],inv(Fps_5000_h0_neff)[0,2]],[inv(Fps_5000_h0_neff)[2,0],
                                                                inv(Fps_5000_h0_neff)[2,2]]])


xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$H_0$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<3000,P:2<\ell<5000)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mean,sigmap,colors = 'r')
cs1=sig_contours(mean,sigmaps,colors = 'k')

fmt1=dict(zip(cs1.levels,[r'$\textit{Planck}$+$\rm{SPT3G}$',r'$\textit{Planck}$+$\rm{SPT3G}$']))
fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs1,cs1.levels[::2], inline=True, fmt=fmt1,fontsize=14)
errorbar(mean[1],mean[0],yerr = sqrt(inv(Fp_5000_h0[0])[0,0]),color='r',elinewidth=8,label='Planck LCDM constraint on H0')
errorbar(mean[1],mean[0],yerr = sqrt(inv(Fps_5000_h0)[0,0]),color='k',elinewidth=6,label='Planck +SPT3G')

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
legend(loc='upper left')
tight_layout()
ylim(62,82)
xlim(2,4)
savefig('Figures/H0_Neff_constraints_planck_and_planckSPT3G.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mean = [72.5,3.046]
sigmap = array([[inv(Fp_800_h0_neff[0])[0,0],inv(Fp_800_h0_neff[0])[0,2]],[inv(Fp_800_h0_neff[0])[2,0],
                                                                    inv(Fp_800_h0_neff[0])[2,2]]])

sigmaps_800 = array([[inv(Fps_800_5000_h0_neff)[0,0],inv(Fps_800_5000_h0_neff)[0,2]],
                     [inv(Fps_800_5000_h0_neff)[2,0],inv(Fps_800_5000_h0_neff)[2,2]]])

xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$H_0$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<800,P:2<\ell<800)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mean,sigmap,colors = 'r')
cs3=sig_contours(mean,sigmaps_800,colors = 'g')

fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))
fmt3=dict(zip(cs3.levels,[r'$\textit{Planck}$+$\rm{SPT3G}$',r'$\textit{Planck}$+$\rm{SPT3G}$']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs3,cs3.levels[::2], inline=True, fmt=fmt3, fontsize=14)
errorbar(mean[1],mean[0],yerr = sqrt(inv(Fp_800_h0[0])[0,0]),color='r',elinewidth=8,label='Planck LCDM constraint on H0')
errorbar(mean[1],mean[0],yerr = sqrt(inv(Fps_800_5000_h0)[0,0]),color='g',elinewidth=6,label='Planck +SPT3G')

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
legend(loc='upper left')
tight_layout()
ylim(62,82)
xlim(2,4)
savefig('Figures/H0_Neff_constraints_planck_and_planck_800SPT3G.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sqrt(inv(Fps_5000_h0)[0,0]),sqrt(inv(Fps_800_5000_h0)[0,0])
# Out:
# (0.34489220906637885, 0.36091043558464625)

# %%
mean = [0.0223,3.046]
sigmap = array([[inv(Fp_5000_h0_neff[0])[4,4],inv(Fp_5000_h0_neff[0])[4,2]],[inv(Fp_5000_h0_neff[0])[2,4],
                                                                    inv(Fp_5000_h0_neff[0])[2,2]]])
sigmaps = array([[inv(Fps_5000_h0_neff)[4,4],inv(Fps_5000_h0_neff)[4,2]],[inv(Fps_5000_h0_neff)[2,4],
                                                                inv(Fps_5000_h0_neff)[2,2]]])


xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$\Omega_bh^2$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<3000,P:2<\ell<5000)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mean,sigmap,colors = 'r')
cs1=sig_contours(mean,sigmaps,colors = 'k')

fmt1=dict(zip(cs1.levels,[r'$\textit{Planck}$+$\rm{SPT3G}$',r'$\textit{Planck}$+$\rm{SPT3G}$']))
fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs1,cs1.levels[::2], inline=True, fmt=fmt1,fontsize=14)

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
tight_layout()
savefig('Figures/omegabh2_Neff_constraints_planck_and_planckSPT3G.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mean = [0.0223,3.046]
sigmap = array([[inv(Fp_800_h0_neff[0])[4,4],inv(Fp_800_h0_neff[0])[4,2]],[inv(Fp_800_h0_neff[0])[2,4],
                                                                    inv(Fp_800_h0_neff[0])[2,2]]])

sigmaps_800 = array([[inv(Fps_800_5000_h0_neff)[4,4],inv(Fps_800_5000_h0_neff)[4,2]],
                     [inv(Fps_800_5000_h0_neff)[2,4],inv(Fps_800_5000_h0_neff)[2,2]]])

xlab = r'$\rm{N}_{\rm{eff}}$'
ylab = r'$\Omega_bh^2$'
titl='$SPT3G(T:200<\ell<3000,P:200<\ell<5000)$'+ \
'\n $Planck(T:2<\ell<800,P:2<\ell<800)$'+ \
'\n $LCDM$+$N_{eff}$'

matplotlib.rc('text', usetex = True)
figure()
cs2=sig_contours(mean,sigmap,colors = 'r')
cs3=sig_contours(mean,sigmaps_800,colors = 'g')

fmt2=dict(zip(cs2.levels,[r'$\textit{Planck}$',r'$\textit{Planck}$']))
fmt3=dict(zip(cs3.levels,[r'$\textit{Planck}$+$\rm{SPT3G}$',r'$\textit{Planck}$+$\rm{SPT3G}$']))


clabel(cs2,cs2.levels[::2], inline=True, fmt=fmt2,fontsize=14)
clabel(cs3,cs3.levels[::2], inline=True, fmt=fmt3, fontsize=14)

xlabel(xlab,fontsize=14)
ylabel(ylab,fontsize=14)
title(titl)
tight_layout()
savefig('Figures/omegabh2_Neff_constraints_planck_and_planck_800SPT3G.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
params={'H0':None,'cosmomc_theta': fish_param(1.0438e-2,1.3e-5),
                           'ombh2':fish_param(0.0223,0.001),
                           'ommh2':fish_param(0.13,0.007),
                           'tau':fish_param(0.083,0.02, 0.02),
                           'clamp':fish_param(1.93e-09,4.5e-11),
                           'ns':fish_param(0.9623,0.032),
                           'nnu':fish_param(3.046,0.03),
                           
                           'lmax':6000,'lens_potential_accuracy':2.0}

# %%
results=[]
for fsky in arange(.1,.9,.1):
    s4cov=create_basic_cov(fsky,.0003,"Models/COVS/s4.p",
                     noise=(sqrt(fsky/.4),'ukarc'),
                     time= 3.7e7,
                     windowrange = slice(30,5000),
                     bin_size = 24,
                     spectra=('TT','EE','TE'),
                     save=False
                     )
    Fs4=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],s4cov),
                 planck_model(specrange = [('TT',slice(30,3000)),('EE',slice(30,5000)),('TE',slice(30,5000))]))[0]
    results.append((fsky,sqrt(inv(Fs4)[2,2])))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-69-d7571302f013> in <module>()
#      11     s4cov['EEEE']=s4cov['EEEE']/2
#      12     Fs4=Fisher_Matrix(params,make_full_cov(['TT','EE','TE'],s4cov),
# ---> 13                  planck_model(specrange = [('TT',slice(30,3000)),('EE',slice(30,5000)),('TE',slice(30,5000))]))[0]
#      14     results.append((fsky,sqrt(inv(Fs4)[2,2])))
#
# /nfs/home/kmaylor/Forecasting/Fisher_CMB.py in Fisher_Matrix(params, cov, model, show_results)
#      67                                                                                if isinstance(v,fish_param)])
#      68     else:
# ---> 69         FM=(add_priors(params,Fisher_Calc(derivative(model,params),cov)), [k for k,v in params.items()
#      70                                                                            if isinstance(v,fish_param)])
#      71
#
# /nfs/home/kmaylor/Forecasting/Fisher_CMB.py in Fisher_Calc(model_der, cov)
#      39     Calculate the Fisher Matrix for a given model and covariance.
#      40     """
# ---> 41     cho_cov = cho_factor(cov)
#      42     return dot(model_der,cho_solve(cho_cov,model_der.T))
#      43
#
# /nfs/home/kmaylor/.virtualenvs/Forecasting_env/local/lib/python3.4/site-packages/scipy/linalg/decomp_cholesky.py in cho_factor(a, lower, overwrite_a, check_finite)
#     130     """
#     131     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
# --> 132                             check_finite=check_finite)
#     133     return c, lower
#     134
#
# /nfs/home/kmaylor/.virtualenvs/Forecasting_env/local/lib/python3.4/site-packages/scipy/linalg/decomp_cholesky.py in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      28     c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      29     if info > 0:
# ---> 30         raise LinAlgError("%d-th leading minor not positive definite" % info)
#      31     if info < 0:
#      32         raise ValueError('illegal value in %d-th argument of internal potrf'
#
# LinAlgError: 418-th leading minor not positive definite

# %%
fskys,Neffs=zip(*results)

# %%
plot(fskys,array(Neffs))
# Out:
# <img src="data:image/png;base64,..." width="640">
